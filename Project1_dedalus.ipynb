# %% [markdown]
# <a href="https://colab.research.google.com/github/johnryantaylor/QCES/blob/main/Project1_dedalus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solving the diffusion equation with Dedalus

# %% [markdown]
# **Overview:** This notebook solves the diffusion equation using a spectral method and provides an introduction to Dedalus.
#
# **About Dedalus:** [Dedalus](http://dedalus-project.org) is an open-source Python package for solving partial differential equations (PDEs) using spectral methods.
# These methods provide highly accurate numerical solutions for PDEs with smooth solutions in simple domains like boxes and spheres.
# Dedalus implements modern parallel algorithms utilizing sparse polynomial bases, but all with an easy-to-use symbolic interface.
# The code is being used in a wide range of fields, often for problems involving fluid dynamics.
#
# This script is based in part on the Introduction to Dedalus by [Keaton Burns](http://keaton-burns.com)
#
# The student exercise starts in [Section 5](#student_investigation)

# %% [markdown]
# # 1.

# %% [markdown]
# First, we need to install Dedalus.  If you are running Python on your local computer, follow the install instructions in the [Dedalus Docs](https://dedalus-project.readthedocs.io/en/latest/pages/installation.html) to install Dedalus locally on your computer.
#
# The cell below checks to see if Dedalus is installed.  After installing Dedalus, run the cell below to verify that Dedalus is installed correctly.
#
# If you are using Google Colab, the cell below will automatically install Dedalus.
#
# This cell checks if Dedalus is installed and performs some other basic setup. This will take some time the first time you run it.
#
# Once you have Dedalus installed, you won't need to run this cell again.

# %%
# Set environment variables for best performance
# %env OMP_NUM_THREADS=1
# %env NUMEXPR_MAX_THREADS=1

# Minimize logging output
import logging
logging.disable(logging.DEBUG)

# Check if running on google colab
import os
using_google_colab = bool(os.getenv("COLAB_RELEASE_TAG"))

# Check for Dedalus
try:
    import dedalus.public as de
    print("Dedalus already installed :)")
except:
    print("Dedalus not installed yet.")
    if using_google_colab:
        print("Installing for Google Colab.")
        print()
        # Step 1: Install FFTW
        # !apt-get install libfftw3-dev
        # !apt-get install libfftw3-mpi-dev
        # Step 2: Set paths for Dedalus installation
        import os
        os.environ['MPI_INCLUDE_PATH'] = "/usr/lib/x86_64-linux-gnu/openmpi/include"
        os.environ['MPI_LIBRARY_PATH'] = "/usr/lib/x86_64-linux-gnu"
        os.environ['FFTW_INCLUDE_PATH'] = "/usr/include"
        os.environ['FFTW_LIBRARY_PATH'] = "/usr/lib/x86_64-linux-gnu"
        # Step 3: Install Dedalus using pip
        # !pip3 install cython "mpi4py<4.0" numpy setuptools wheel
        # !CC=mpicc pip3 install --no-cache --no-build-isolation http://github.com/dedalusproject/dedalus/zipball/master/
        # !pip3 install -q ipympl
        # Step 4: Check installation
        print()
        try:
            import dedalus.public as de
            print("Dedalus successfully installed :)")
        except:
            print("Error installing Dedalus :(")
            raise
    else:
        print("See website for installation instructions:")
        print("https://dedalus-project.readthedocs.io/en/latest/pages/installation.html")

# Setup interactive matplotlib
if using_google_colab:
    from google.colab import output
    output.enable_custom_widget_manager()
# Out:
# env: OMP_NUM_THREADS=1
# env: NUMEXPR_MAX_THREADS=1
# Dedalus already installed :)

# %% [markdown]
# At the start of each Python script, we need to import the packages that we will use.  The cell below imports the packages that will be needed here, namely numpy, matplotlib (for plotting) and dedalus. Note that we assign aliases for numpy, matplotlib, and dedlaus. Run this cell before running any of the cells below.

# %%
import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as dedalus
import logging
logger = logging.getLogger(__name__)

# %% [markdown]
# ## 2. Dedalus basics

# %% [markdown]
# Dedalus solves PDEs using spectral methods.  Dedalus requires us to specify the spatial coordinates, the `distributor`, and the spectral bases, which are explained below.

# %% [markdown]
# ### Coordinates

# %% [markdown]
# We can use a variety of coordinate systems in Dedalus. For example, for multi-dimensional problems, we can use Cartesian coordinates, polar coordinates, spherical coordinates, etc. Here, we will set up a 1D problem using the Dedalus `Coordinate` class. We will see other examples in future projects.
# For more details on other problem types, included distributed parallel simulations, see the official [Dedalus Tutorial 1](https://dedalus-project.readthedocs.io/en/latest/notebooks/dedalus_tutorial_1.html).
#
# Let's create a coordinate object representing our 1D coordinate, which here we will call `x`:

# %%
xcoord = dedalus.Coordinate('x')

# %% [markdown]
# ### Distributors

# %% [markdown]
# Dedalus uses MPI (Message Passing Interface) for allow parallel computation on distributed memory systems. There are various options for how to distribute the computation amongst the processes. In Dedalus this is done by an object called a `Distributor`. Here, we will run not run in paralle, but Dedalus still requies us to create a `Distributor` object. You don't need to worry about this now, we will discuss it further in later projects.
#
# The line below creates a distributor for our x coordinate for a problem with real variables.

# %%
dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization

# %% [markdown]
# ### Spectral basis

# %% [markdown]
# Dedalus decomposes the PDE that we are solving using a spectral basis. Dedalus has the ability to use different basis functions for this decomposition, and this gives Dedalus remarkable flexibility. For example, `RealFourier` provides a Fouier basis (sine and cosine functions) can be used for problems that are periodic (cyclic) in physical space. The `Chebyshev` basis allows boundary conditions to be set on a finite interval. The `SphereBasis` allows us to solve problems on a sphere.
#
# The line below creates a Fourier basis for a real-valued system with a domain size of Lx=10 and with Nx=1024 gridpoints in physical space.

# %%
# Set some parameters
Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
x_start=-1; x_end=1 # The starting and ending bounds on x

# Construct a Fourier basis
x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))

# %% [markdown]
# ### Grids

# %% [markdown]
# Each basis has a corresponding grid in physical space that can be used for tasks like initializing and plotting fields.
#
# The line below creates a grid for the x coordinate.

# %%
x = dist.local_grid(x_basis)

# %% [markdown]
# ### Fields

# %% [markdown]
# `Field` objects in Dedalus represent scalar-valued fields defined over a set of bases (or a "domain").
# For multidimensional problems, vector and tensor valued fields can also be constructed using the `VectorField` and `TensorField` clases.
#
# Let's construct a field called `c` (for concentration) using our 1D basis:

# %%
c = dist.Field(name='c', bases=x_basis)

# %% [markdown]
# Field objects have internal methods for transforming their data between grid (`'g'`) and coefficeint (`'c'`) space representations.
# The field's values can be assigned and retrieved by indexing a field with these strings.
#
# Let's set the grid-space values of our field, `c`, to be a Gaussian function of `x`. This is how we set the initial condition for the initial value problem that we will solve below.

# %%
w = 0.1 # Set the width of the initial Gaussian
c.change_scales(1) # Set values on regular grid
c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

plt.figure(figsize=(6, 3)) # Set the size of the figure
plt.plot(x, c['g']) # Plot the "grid-space" initial conditions
plt.xlabel('x'); plt.ylabel("c"); # Set the axis labels

# %% [markdown]
# As a bit of an aside, we can find the coefficients of the spectral representation of a field using ['c'] instead of ['g'].
# This triggers an in-place spectral (in this case Fourier) transform of the field's data.
# For the `RealFourier` basis, the coefficients are the interleaved real-valued coefficients of the cosine and (negative) sine coefficients.
# For very large problems transforming between grid and coefficient space will be time-consuming, so you will want to limit the number of times that this is done.

# %%
k = np.pi * np.arange(1, Nx/2+1) / (x_end - x_start) # Create an array of wavenumbers, k(i)=i*pi/Lx
plt.figure(figsize=(6, 3))
plt.plot(k, c['c'][0::2], label='cosine amplitude')
plt.plot(k, -c['c'][1::2], label='sine amplitude')
plt.xlabel('wavenumber (k)')
plt.ylabel("c['c']")
plt.xlim(0, 50)
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## 3. Problems and Solvers

# %% [markdown]
# Dedalus uses Problem and Solver classes to specify the problem and the methods that will be used to solve it. Here, we will set up the diffusion equation and solve it using the Crank-Nicolson timestepping method.
#
# For more details on other problem types, see [Dedalus Tutorial 3](https://dedalus-project.readthedocs.io/en/latest/notebooks/dedalus_tutorial_2.html).

# %% [markdown]
# ### Problems

# %% [markdown]
# Dedalus standardizes the formulation of all initial value problems by taking systems of symbolically specified equations and boundary conditions specified in the following generic form:
#
# $$\mathcal{M} \cdot \partial_t \mathcal{X} + \mathcal{L} \cdot \mathcal{X} = \mathcal{F}(\mathcal{X}, t)$$
#
# where $\mathcal{M}$ and $\mathcal{L}$ are matrices of linear differential operators, $\mathcal{X}$ is a state vector of the unknown fields, $\mathcal{F}$ is a vector of general nonlinear expressions.
#
# The left-hand side (LHS) of the equations must be first-order in temporal derivatives and linear in the problem variables.
# The right-hand side (RHS) of the equations may contain nonlinear and time-dependent terms, but no temporal derivatives.
#
# When using a mixed implicit/explicit timestepping scheme, Dedalus will apply the implicit method to the $\mathcal{L}\cdot \mathcal{X}$ term and the explicit method to the $\mathcal{F}(\mathcal{X}, t)$ term.
#
# To create a problem object, we provide a list of the variables to be solved for. In this case, this is just `c`.
#
# Equations can then be entered as pairs of operator expressions like `(LHS, RHS)` or as strings like `"LHS = RHS"`.
#
# Here, let's set up the diffusion equation:
#
# $$\partial_t c - \kappa \partial_x^2 c = 0$$
#
# Note that we put the term with the second derivative on the left hand side of the equation so that it will be time-stepped implicitly.

# %%
# Parameters
kappa = 0.001

# Operators
dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

# Specify the problem
problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
problem.add_equation("dt(c) - kappa*dx(dx(c)) = 0"); # Write out the equation to be solved

# %% [markdown]
# ### 3.2 Solvers

# %% [markdown]
# Now, we need to specify the solver.  For IVPs, we specify a timestepping method when building the solver. Below we select the `CNAB1` timestepper which uses Crank-Nicolson for the $\mathcal{L}\cdot \mathcal{X}$ term and the explicit first order Adams-Bashforth method for the right hand side term (but in this case the RHS is zero).

# %%
timestepper = dedalus.CNAB1
solver = problem.build_solver(timestepper)
# Out:
# 2024-11-15 16:06:31,110 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+01/s

# %% [markdown]
# Next, we need to specify a condition for the simulation to end. This can be a set number of iterations (set using `solver.stop_iteration`), a stopping time in simulation time units (set using `solver.stop_sim_time`, or a maximum wall clock time in seconds (set using `solver.stop_wall_time`).

# %%
solver.stop_sim_time = 10 # Stop at 10 simulation time units

# %% [markdown]
# IVPs are iterated using the `solver.step` method with a provided timestep.
# The logic controlling the main-loop of a Dedalus IVP simulation occurs explicitly in the simulation script.
# The `solver.proceed` property will change from `True` to `False` once any of the specified stopping criteria have been met.
# Let's timestep our problem until the halting condition is reached, copying the grid values of `u` every few iterations.
# This should take just a few seconds to run.

# %%
# Main loop
timestep = 0.1
c.change_scales(1)
c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
while solver.proceed:
    solver.step(timestep)
    if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
        logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
    # save the values of c and t
    c.change_scales(1)
    c_save.append(np.copy(c['g']))
    t_save.append(solver.sim_time)
# Out:
# 2024-11-15 16:06:31,151 solvers 0/1 INFO :: Simulation stop time reached.

# %% [markdown]
# Now we can make a space-time plot of the solution:

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True, clim=(-1, 1))
plt.xlim(x_start, x_end)
plt.ylim(0, solver.stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.title(f'Diffusion equation with Crank-Nicolson')
plt.tight_layout()

# %% [markdown]
# ## 4. Forced diffusion equation

# %% [markdown]
# Dedalus is extremely flexible, which will make it very useful throughout the QCES computational projects. For example, it is relatively straightforward to change the equation that we are solving.
#
# In order to introduce functions into the equations that Dedalus solves, we need to define a new operator.  For example, the following code defines the function $sin(x)$ on our grid:

# %%
# Create an operator that applies a function to the variable on a grid
sin_x = dist.Field(bases=x_basis)
sin_x['g'] = np.sin(x)

# %% [markdown]
# The code below uses Dedlaus to solve the forced diffusion equation:
#
# $$\partial_t c - \kappa \partial_x^2 c = cos(\pi x / Lx)$$
#
# with the same Gaussian initial condition as before. This example also shows what a complete Dedalus script looks like.

# %%
# Load the required packages (these were loaded above and are inluded here for completeness)
import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as dedalus
import logging
logger = logging.getLogger(__name__)

# This script solves the forced diffusion equation with Dedlaus

# Set some parameters for the problem to be solved
Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
Lx = 2; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
x_start=-Lx; x_end=Lx # The starting and ending bounds on x
kappa = 0.001 # set the diffusivity

# Create an x-coordinate, a corresponding basis, and a distributor
xcoord = dedalus.Coordinate('x')
dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
x = dist.local_grid(x_basis)



times = [5, 10 , 100 ,500 ,1000 ,4000]
for i in times:
    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    f_x = dist.Field(bases=x_basis)
    f_x['g'] = np.cos(np.pi * x / Lx)

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - kappa * dx(dx(c)) = f_x"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = i # Stop at 10 simulation time units

    # Main loop
    timestep = 1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot
    plt.figure(figsize=(6, 4))
    plt.pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True)#, clim=(-1, 1))
    plt.xlim(x_start, x_end)
    plt.ylim(0, solver.stop_sim_time)
    plt.xlabel('x')
    plt.ylabel('t')
    plt.colorbar()
    plt.title(f'Forced diffusion equation to t= {i}')
    plt.tight_layout()
# Out:
# 2024-11-15 16:06:31,956 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+01/s
# 2024-11-15 16:06:31,958 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:06:31,995 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.8e+02/s
# 2024-11-15 16:06:31,997 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:06:32,035 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.1e+02/s
# 2024-11-15 16:06:32,046 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:06:32,086 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.9e+02/s
# 2024-11-15 16:06:32,134 __main__ 0/1 INFO :: Iteration=500, Time=5.000000e+02, dt=1.000000e+00
# 2024-11-15 16:06:32,134 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:06:32,194 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.9e+02/s
# 2024-11-15 16:06:32,243 __main__ 0/1 INFO :: Iteration=500, Time=5.000000e+02, dt=1.000000e+00
# 2024-11-15 16:06:32,292 __main__ 0/1 INFO :: Iteration=1000, Time=1.000000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,293 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:06:32,382 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.9e+02/s
# 2024-11-15 16:06:32,433 __main__ 0/1 INFO :: Iteration=500, Time=5.000000e+02, dt=1.000000e+00
# 2024-11-15 16:06:32,481 __main__ 0/1 INFO :: Iteration=1000, Time=1.000000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,530 __main__ 0/1 INFO :: Iteration=1500, Time=1.500000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,578 __main__ 0/1 INFO :: Iteration=2000, Time=2.000000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,628 __main__ 0/1 INFO :: Iteration=2500, Time=2.500000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,678 __main__ 0/1 INFO :: Iteration=3000, Time=3.000000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,727 __main__ 0/1 INFO :: Iteration=3500, Time=3.500000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,777 __main__ 0/1 INFO :: Iteration=4000, Time=4.000000e+03, dt=1.000000e+00
# 2024-11-15 16:06:32,777 solvers 0/1 INFO :: Simulation stop time reached.

# %%
# Load the required packages (these were loaded above and are inluded here for completeness)
import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as dedalus
import logging
logger = logging.getLogger(__name__)

# This script solves the forced diffusion equation with Dedlaus

# Set some parameters for the problem to be solved
Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
Lx = 2; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
x_start=-Lx; x_end=Lx # The starting and ending bounds on x
kappa = 0.001 # set the diffusivity

# Create an x-coordinate, a corresponding basis, and a distributor
xcoord = dedalus.Coordinate('x')
dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
x = dist.local_grid(x_basis)

# Set initial conditions
c = dist.Field(name='c', bases=x_basis)
w = 0.1 # Set the width of the initial Gaussian
c.change_scales(1) # Set values on regular grid
c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

# Operators
dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

# Create an operator that applies a function to the variable on a grid
f_x = dist.Field(bases=x_basis)
f_x['g'] = np.cos(np.pi * x / Lx)

# Specify the problem
problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
problem.add_equation("dt(c) - kappa * dx(dx(c)) = f_x"); # Write out the equation to be solved

timestepper = dedalus.CNAB1
solver = problem.build_solver(timestepper)

solver.stop_sim_time = 10 # Stop at 10 simulation time units

# Main loop
timestep = 0.1
c.change_scales(1)
c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
while solver.proceed:
    solver.step(timestep)
    if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
        logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
    c.change_scales(1)
    c_save.append(np.copy(c['g']))
    t_save.append(solver.sim_time)

# Plot
plt.figure(figsize=(6, 4))
plt.pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True)
plt.xlim(x_start, x_end)
plt.ylim(0, solver.stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.axvline(x=1, color='r', linestyle='--')
plt.title('Forced diffusion equation')
plt.tight_layout()
# Out:
# 2024-11-15 16:07:08,965 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+01/s
# 2024-11-15 16:07:08,978 solvers 0/1 INFO :: Simulation stop time reached.

# %% [markdown]
# ## 5. Student investigation
# <a id='student_investigation'></a>

# %% [markdown]
# ### 5.1 Steady-state solution to the forced diffusion equation

# %% [markdown]
# For the forced diffusion equation described in section 4, using dimensional analysis, estimate the time needed to reach a steady-state solution. Test this scaling, and discuss your results below. Run the code above for a sufficient time to achieve a steady-state solution. Plot $c$ at the end of this simulation, and compare it with the exact steady-state solution to the forced diffusion equation.

# %% [markdown]
# Students should comment on the timescale needed to transition from the initial condition to the forced solution, and comment on the diffusive and forcing timescales.

# %% [markdown]
# **Dimensional analysis**
#
# $$\frac{c}{t} \sim \frac{\Kappa C}{L^2} \sim cos(\frac{\pi x}{Lx}) $$
#
# For early times:
# - Set L to be lengthscale of gaussian = w = 0.1. Now the diffusive term in the scaling is small, since $\frac{\kappa C_0}{L^2} =0.1 <<1$
#
# As a result
# $$\frac{c}{t} \sim cos(\frac{\pi x}{Lx}) $$
# so
# $$c \sim t cos(\frac{\pi x}{Lx}) ~ (*) $$
#
# So initial evolution is set by the forcing timescale, where c grows linearly. From above the forced solution is acheived within ~10 seconds.
# Noting that the amplitude of the cosine term increase linearly with $t$, $c$ increases and therefore $\frac{\partial^2 c}{\partial x^2}$ does too, which will eventually be large enough in magnitude to balance forcing term. This is when the diffusive timescale becomes relevent:
#
# Using equation $(*)$, and with $\Kappa \frac{\partial^2 c}{\partial x^2} = 1$ to be on scale with forcing (steady state) $$\Kappa \frac{\partial^2 c}{\partial x^2} \sim \Kappa \frac{t}{Lx^2} $$
# so
# $$t \sim  \frac{Lx^2}{\Kappa} $$
#
# Substituting $Lx$ as the full length scale (= 2), $ t\sim 4000$
#
# As tested above, changing timescale from 10 to 100 to 1000 shows that complete diffusion of the forced source is being approached at around t~ 1000, on the order of the characteristic timescale. A further run to t=4000 confirms this, with steady state achieved and not changing much to t=8000 (but needed larger timesteps for computing efficiency). From this point concentration is constant across x and increases with t.
#
#
#
# ** For early times t will scale with either cos or diffusive function, but at steady state c becomes big enough for the others to balance **

# %%
print((2*Lx)**2/kappa)
# Out:
# 16000.0

# %% [markdown]
# **Comparison to exact steady state solution**

# %%
#Exact solution: 
def diff_exact(x, kappa, Lx):
    return (Lx/np.pi)**2*1/kappa *(np.cos(np.pi*x/Lx)-np.cos(np.pi/Lx))


plt.plot(x, c['g'], label='Numerical') # will plot values for last stored time 
plt.plot(x, diff_exact(x, kappa, Lx), label='Exact')
plt.xlim(-1,1)
plt.xlabel('x')
plt.ylabel('c')
plt.legend()
plt.show()

# %%
ts = [5, 10, 100, 500, 1000, 4000]
print(enumerate(ts))
# Out:
# <enumerate object at 0x144063600>

# %%
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()

ts = [5, 10, 100, 500, 1000, 4000]

for j,i in enumerate(ts): 
    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    f_x = dist.Field(bases=x_basis)
    f_x['g'] = np.cos(np.pi * x / Lx)

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - kappa * dx(dx(c)) = f_x"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = i # Stop at 10 simulation time units

    # Main loop
    timestep = 1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)


    axs[j].plot(x, c['g'], label=f'Numerical for t= {i}')
    axs[j].plot(x, diff_exact(x, kappa, Lx), label='Exact')
    axs[j].set_xlim(-1,1)
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('concentration')
    axs[j].legend()
plt.tight_layout()
plt.show()
# Out:
# 2024-11-15 16:07:09,859 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2024-11-15 16:07:09,905 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:07:09,919 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.3e+02/s
# 2024-11-15 16:07:09,921 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:07:09,929 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.5e+02/s
# 2024-11-15 16:07:09,940 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:07:09,947 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.9e+02/s
# 2024-11-15 16:07:09,995 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:07:10,002 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.7e+02/s
# 2024-11-15 16:07:10,095 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 16:07:10,102 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.8e+02/s
# 2024-11-15 16:07:10,464 solvers 0/1 INFO :: Simulation stop time reached.

# %%
len(t_save)
range(len(t_save))
# Out:
# range(0, 4001)

# %%
error_diff = np.zeros(len(t_save))
for i in range(len(t_save)):
    error_diff[i] = np.sum(np.abs(c_save[i]-diff_exact(x, kappa, Lx)))/Nx

fig, ax= plt.subplots(1, 2, figsize=(10,5))
ax[0].plot(t_save, error_diff)
ax[1].plot(t_save, error_diff, color = 'C2', label='Log scale')
ax[1].set_yscale('log')
ax[0].set_xlabel('Time')
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Absolute difference between exact and numerical solution')
ax[1].legend()
fig.suptitle('Error of numerical solution compared to exact \n steady-state forced diffusion solution for different times');

# %% [markdown]
# **The above plots show that the numerical solution converges to the exact steady state solution at around 2000 time units, with error reaching a minimum after ~3600 time units. We can interpret this to mean that the diffusive term becomes important early but does not grow significant enough to balance forcing until around 2000 units, on the order of the predicted 4000**

# %% [markdown]
# ### 5.2 Variable difusivity

# %% [markdown]
# In some applications of the diffusion equation, the diffusivity varies in space. This happens, for example, in the movement of pollution in groundwater flowing through soil of variable porosity, or the mixing of tracers due to turbulence in the ocean (which we will explore in detail in Project 2).
#
# In the code cell below, write a Dedalus script that solves the following equation:
#
# $$\partial_t c - \partial_x(\kappa (x) \partial_x c) = 0$$
#
# where
#
# $$\kappa(x)=\kappa_0(tanh(x/0.1)+1)/2$$
#
# and $\kappa_0=0.001$. It is fine to start by copying the code in the previous cell and changing the problem equation appropriately.

# %%
# Write a Dedalus script to solve the diffusion equation with a spatially-variable diffusivity
# It is fine to copy and paste the scripts above as a starting point.

logger = logging.getLogger(__name__)

# Set some parameters for the problem to be solved
Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
Lx = 1; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
x_start=-Lx; x_end=Lx # The starting and ending bounds on x
k_0 = 0.001

# Create an x-coordinate, a corresponding basis, and a distributor
xcoord = dedalus.Coordinate('x')
dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
x = dist.local_grid(x_basis)

# Set initial conditions
c = dist.Field(name='c', bases=x_basis)
w = 0.1 # Set the width of the initial Gaussian
c.change_scales(1) # Set values on regular grid
c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

# Operators
dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

# Create an operator that applies a function to the variable on a grid
g_x = dist.Field(bases=x_basis)
g_x['g'] = k_0 *(np.tanh(x/0.1)+1.1)/2

# Specify the problem
problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

timestepper = dedalus.CNAB1
solver = problem.build_solver(timestepper)

solver.stop_sim_time = 10 # Stop at 10 simulation time units

# Main loop
timestep = 0.1
c.change_scales(1)
c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
while solver.proceed:
    solver.step(timestep)
    if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
        logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
    c.change_scales(1)
    c_save.append(np.copy(c['g']))
    t_save.append(solver.sim_time)

# Plot
plt.figure(figsize=(6, 4))
plt.pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True)
plt.xlim(x_start, x_end)
plt.ylim(0, solver.stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.title('Diffusion equation')
plt.tight_layout()
# Out:
# 2024-11-15 17:44:53,858 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.6e+00/s
# 2024-11-15 17:44:54,027 solvers 0/1 INFO :: Simulation stop time reached.

# %%
plt.plot(x,g_x['g'])
plt.axvline(x=0.25, color='r', linestyle='--', label='x=0.25')
plt.xlabel('x')
plt.ylabel('Diffusivity (Kappa)')
plt.legend();
print("Diffusivity at x=-1 is ",g_x['g'][1])
print("Diffusivity at x=-1 is ",g_x['g'][1023])
# Out:
# Diffusivity at x=-1 is  4.9511720895273564e-05
# Diffusivity at x=-1 is  0.0010495117166087523

# %%
#Testing different initial diffusivity values 
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()
kappas = np.logspace (-4,-1.5,6)
for j,i in enumerate(kappas):

    logger = logging.getLogger(__name__)
    # Set some parameters for the problem to be solved
    Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
    Lx = 2; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
    x_start=-Lx; x_end=Lx # The starting and ending bounds on x
    kappa_0 = i

    # Create an x-coordinate, a corresponding basis, and a distributor
    xcoord = dedalus.Coordinate('x')
    dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
    x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
    x = dist.local_grid(x_basis)

    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    g_x = dist.Field(bases=x_basis)
    g_x['g'] = kappa_0 *(np.tanh(x/0.1)+1.1)/2

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = 10 # Stop at 10 simulation time units

    # Main loop
    timestep = 0.1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot
    plot = axs[j].pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True)
    axs[j].set_xlim(x_start, x_end)
    axs[j].set_ylim(0, solver.stop_sim_time)
    axs[j].set_title(f'Initial Kappa = {i:.2e}')
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('t')

#cbar = fig.colorbar(plot, ax = axs, orientation = 'horizontal', pad = 0.01)
fig.suptitle('Diffusion with spatial variability in diffusivity across a range of initial Kappa values')
plt.tight_layout()
# Out:
# 2024-11-15 17:20:33,990 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.6e+01/s
# 2024-11-15 17:20:34,029 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:20:34,116 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-11-15 17:20:34,262 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:20:34,475 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:20:34,645 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:20:35,865 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 1s, Remaining: 0s, Rate: 8.3e-01/s
# 2024-11-15 17:20:36,118 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:20:37,374 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 1s, Remaining: 0s, Rate: 8.0e-01/s
# 2024-11-15 17:20:37,619 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:20:38,905 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 1s, Remaining: 0s, Rate: 7.8e-01/s
# 2024-11-15 17:20:39,147 solvers 0/1 INFO :: Simulation stop time reached.

# %%
#Testing different initial diffusivity values 
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()
axs
kappas = np.logspace (-4,-1.5,6)
for j,i in enumerate(kappas):

    logger = logging.getLogger(__name__)
    # Set some parameters for the problem to be solved
    Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
    Lx = 2; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
    x_start=-Lx; x_end=Lx # The starting and ending bounds on x
    kappa_0 = i

    # Create an x-coordinate, a corresponding basis, and a distributor
    xcoord = dedalus.Coordinate('x')
    dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
    x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
    x = dist.local_grid(x_basis)

    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    g_x = dist.Field(bases=x_basis)
    g_x['g'] = kappa_0 *(np.tanh(x/0.1)+1.1)/2

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = 10 # Stop at 10 simulation time units

    # Main loop
    timestep = 0.1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot

    axs[j].plot(x, g_x['g'])
    axs[j].axvline(x=0.25, color='r', linestyle='--', label='x=0.25')
    axs[j].set_xlim(x_start, x_end)
    axs[j].set_title(f'Initial Kappa = {i:.2e}')
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('Diffusivity')
    axs[j].legend()

#cbar = fig.colorbar(plot, ax = axs, orientation = 'horizontal', pad = 0.01)
fig.suptitle('Diffusion with spatial variability in diffusivity across a range of initial Kappa values')
plt.tight_layout()
# Out:
# 2024-11-15 17:26:10,363 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.4e+01/s
# 2024-11-15 17:26:10,402 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:26:10,487 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-11-15 17:26:10,615 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:26:10,821 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-11-15 17:26:10,985 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:26:12,224 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 1s, Remaining: 0s, Rate: 8.1e-01/s
# 2024-11-15 17:26:12,493 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:26:13,764 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 1s, Remaining: 0s, Rate: 7.9e-01/s
# 2024-11-15 17:26:14,011 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:26:15,356 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 1s, Remaining: 0s, Rate: 7.5e-01/s
# 2024-11-15 17:26:15,597 solvers 0/1 INFO :: Simulation stop time reached.

# %%
c_save = np.array(c_save)
plt.plot(t_save, c_save[:,512])
plt.ylim(-10,2)
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
#Testing different diffusivity scalings
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()
scaling = np.logspace(-3,2,6)
for j,i in enumerate(scaling):

    logger = logging.getLogger(__name__)
    # Set some parameters for the problem to be solved
    Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
    Lx = 1; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
    x_start=-Lx; x_end=Lx # The starting and ending bounds on x
    kappa_0 = 0.001

    # Create an x-coordinate, a corresponding basis, and a distributor
    xcoord = dedalus.Coordinate('x')
    dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
    x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
    x = dist.local_grid(x_basis)

    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    g_x = dist.Field(bases=x_basis)
    g_x['g'] = kappa_0 *(np.tanh(x/i)+1.1)/2

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = 10 # Stop at 10 simulation time units

    # Main loop
    timestep = 0.1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot
    plot = axs[j].pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True)
    axs[j].set_xlim(x_start, x_end)
    axs[j].set_ylim(0, solver.stop_sim_time)
    axs[j].set_title(f'Spatial scaling factor = {i}')
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('t')

#cbar = fig.colorbar(plot, ax = axs, orientation = 'horizontal', pad = 0.01)
fig.suptitle('Diffusion with spatial variability in diffusivity across a range of spatial scaling values')
plt.tight_layout()
# Out:
# 2024-11-15 17:31:27,152 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+00/s
# 2024-11-15 17:31:27,234 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:31:27,442 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-11-15 17:31:27,604 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:31:27,817 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:31:27,989 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:31:28,167 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-11-15 17:31:28,332 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:31:28,381 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.6e+01/s
# 2024-11-15 17:31:28,419 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:31:28,451 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.3e+01/s
# 2024-11-15 17:31:28,465 solvers 0/1 INFO :: Simulation stop time reached.

# %%
#Testing different diffusivity scalings
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()
scaling = np.logspace(-3,0,6)
for j,i in enumerate(scaling):

    logger = logging.getLogger(__name__)
    # Set some parameters for the problem to be solved
    Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
    Lx = 1; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
    x_start=-Lx; x_end=Lx # The starting and ending bounds on x
    kappa_0 = 0.001

    # Create an x-coordinate, a corresponding basis, and a distributor
    xcoord = dedalus.Coordinate('x')
    dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
    x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
    x = dist.local_grid(x_basis)

    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    g_x = dist.Field(bases=x_basis)
    g_x['g'] = kappa_0 *(np.tanh(x/i)+1.1)/2

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = 10 # Stop at 10 simulation time units

    # Main loop
    timestep = 0.1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot
    axs[j].plot(x, g_x['g'])
    # axs[j].axvline(x=0.25, color='r', linestyle='--', label='x=0.25')
    axs[j].set_xlim(x_start, x_end)
    axs[j].set_title(f'Lengthscale = {i:.2e}')
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('Diffusivity')
    # axs[j].legend()

#cbar = fig.colorbar(plot, ax = axs, orientation = 'horizontal', pad = 0.01)
fig.suptitle('Diffusion with spatial variability in diffusivity across a range of spatial scaling values')
plt.tight_layout()
# Out:
# 2024-11-15 17:40:06,593 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.5e+00/s
# 2024-11-15 17:40:06,677 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:40:06,849 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-11-15 17:40:07,006 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:40:07,227 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.7e+00/s
# 2024-11-15 17:40:07,397 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:40:07,607 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:40:07,775 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:40:07,982 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:40:08,152 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:40:08,318 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-11-15 17:40:08,481 solvers 0/1 INFO :: Simulation stop time reached.

# %%
#Testing different diffusivity scalings
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()
constant = np.linspace (0.001,10,6)
for j,i in enumerate(constant):

    logger = logging.getLogger(__name__)
    # Set some parameters for the problem to be solved
    Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
    Lx = 1; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
    x_start=-Lx; x_end=Lx # The starting and ending bounds on x
    kappa_0 = 0.001

    # Create an x-coordinate, a corresponding basis, and a distributor
    xcoord = dedalus.Coordinate('x')
    dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
    x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
    x = dist.local_grid(x_basis)

    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    g_x = dist.Field(bases=x_basis)
    g_x['g'] = kappa_0 *(np.tanh(x/0.1)+ i)/2

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = 10 # Stop at 10 simulation time units

    # Main loop
    timestep = 0.1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot
    plot = axs[j].pcolormesh(x.ravel(), np.array(t_save), np.array(c_save), cmap='RdBu_r', shading='gouraud', rasterized=True)
    axs[j].set_xlim(x_start, x_end)
    axs[j].set_ylim(0, solver.stop_sim_time)
    axs[j].set_title(f'Constant = {i}')
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('t')

#cbar = fig.colorbar(plot, ax = axs, orientation = 'horizontal', pad = 0.01)
fig.suptitle('Diffusion with spatial variability in diffusivity across a range of spatial scaling values')
plt.tight_layout()
# Out:
# 2024-11-15 17:00:12,723 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-11-15 17:00:12,890 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:00:13,101 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-11-15 17:00:13,266 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:00:13,489 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.7e+00/s
# 2024-11-15 17:00:13,660 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:00:13,874 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:00:14,041 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:00:14,254 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:00:14,424 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:00:14,637 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:00:14,804 solvers 0/1 INFO :: Simulation stop time reached.

# %%
#Testing different diffusivity scalings
fig,axs= plt.subplots(3,2, figsize = (10,10))
axs = axs.flatten()
constant = np.linspace (0.001,10,6)
for j,i in enumerate(constant):

    logger = logging.getLogger(__name__)
    # Set some parameters for the problem to be solved
    Nx = 1024 # The number of gridpoints. Note that Fourier transforms are more efficient if this is a power of 2
    Lx = 1; # The domain size in x.  This should be large enough so that the solution goes to zero at the endpoints.
    x_start=-Lx; x_end=Lx # The starting and ending bounds on x
    kappa_0 = 0.001

    # Create an x-coordinate, a corresponding basis, and a distributor
    xcoord = dedalus.Coordinate('x')
    dist = dedalus.Distributor(xcoord, dtype=np.float64) # No mesh for serial / automatic parallelization
    x_basis = dedalus.RealFourier(xcoord, size=Nx, bounds=(x_start, x_end))
    x = dist.local_grid(x_basis)

    # Set initial conditions
    c = dist.Field(name='c', bases=x_basis)
    w = 0.1 # Set the width of the initial Gaussian
    c.change_scales(1) # Set values on regular grid
    c['g'] = np.exp(-x**2/w**2)  # Initialize the dependent variable c with a Gaussian function (note ** is the exponentiation operator)

    # Operators
    dx = lambda a: dedalus.Differentiate(a, xcoord) # Define the derivative (d/dx) operator

    # Create an operator that applies a function to the variable on a grid
    g_x = dist.Field(bases=x_basis)
    g_x['g'] = kappa_0 *(np.tanh(x/0.1)+ i)/2

    # Specify the problem
    problem = dedalus.IVP([c], namespace=locals()) # Initial value problem, including all local variables
    problem.add_equation("dt(c) - dx(g_x * dx(c)) = 0"); # Write out the equation to be solved

    timestepper = dedalus.CNAB1
    solver = problem.build_solver(timestepper)

    solver.stop_sim_time = 10 # Stop at 10 simulation time units

    # Main loop
    timestep = 0.1
    c.change_scales(1)
    c_save = [np.copy(c['g'])]; t_save = [solver.sim_time]; # Save the initial condition and the initial time
    while solver.proceed:
        solver.step(timestep)
        # if solver.iteration % 500 == 0: # Every 500 timesteps, print a message to the screen with the progress
            # logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
        c.change_scales(1)
        c_save.append(np.copy(c['g']))
        t_save.append(solver.sim_time)

    # Plot
    axs[j].plot(x, g_x['g'])
    # axs[j].axvline(x=0.25, color='r', linestyle='--', label='x=0.25')
    axs[j].set_xlim(x_start, x_end)
    axs[j].set_title(f'Constant = {i:.2e}')
    axs[j].set_xlabel('x')
    axs[j].set_ylabel('Diffusivity')
    

#cbar = fig.colorbar(plot, ax = axs, orientation = 'horizontal', pad = 0.01)
fig.suptitle('Diffusion with spatial variability in diffusivity across a range of constant values')
plt.tight_layout()
# Out:
# 2024-11-15 17:39:53,669 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:39:53,830 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:39:54,039 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:39:54,226 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:39:54,436 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:39:54,606 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:39:54,818 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+00/s
# 2024-11-15 17:39:54,988 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:39:55,196 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-11-15 17:39:55,365 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-11-15 17:39:55,580 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+00/s
# 2024-11-15 17:39:55,774 solvers 0/1 INFO :: Simulation stop time reached.

# %% [markdown]
# Explore the behaviour of the solution as you vary the parameters associated with $\kappa(x)$. Comment on your observations below (~1 paragraph)

# %% [markdown]
# **Altering Initial diffusivity ($\kappa_0$):**
#
# The first set of plots above shows a logspace of $\kappa_0$ from $10^{-4}$ to $10^{-1.5}$, with diffusion at lower initial Kappa values very restricted (limited diffusion from origin), and a greater spatial distribution in the positive x direction for increasing $K_0$. This is expected, as increasing this prefactor results in a larger base diffusivity, which also increases in the positive x direction due to the function definition. Diffusivity reaches its maximum value at x = 0.25
#
# For $\kappa_0 > 10^{-1}$ it seems that the diffusion model 'blows up' with values of concentration going rapidly downwards after ~7.5 seconds to -400 at 10 seconds.
#
# **Altering lengthscale of diffusivity increase:**
#
# Varying the factor dividing x in the tanh function corresponds to a sharpening/broadening of the function with respect to x, with lower values resembling a step function up to the maximum value of $\kappa$ and higher values approaching a linear increase. This effect makes the concentration profile more symmetric about x=0 for higher lengthscales, since spatially adjacent gridspaces have more comparable diffusivity values.
#
# **Altering the constant**
#
# The first plot is invalid as diffusivity has negative values for x<0. Further plots show that increasing the constant in the diffusivity expression results in a broader, more smeared concentration profile as diffusivity at all x values is increased by a flat amount. There is less asymmetry apparent at larger values due to the relative difference decreasing: for constant = 1.1 the negative asymptote (x=-1) of the function is $\sim 5 * 10^{-5}$ and the positive asymptote is $1.05*10^{-3}$. In constrast, for constant = 10 the difference is $4.5*10^{-3}$ vs $5.5*10^{-3}$. This 100-fold vs <1 fold increase explains the difference in behaviour

# %% [markdown]
# ## 6. Optional further investigations
#
# * Try writing a Dedalus script to solve the 2D diffusion equation as an initial value problem.  You can look ahead to the the example at the end of the Project 2 notebook for some guidance (but remove the advection term). I would suggest using a Fourier/Fourier basis for this.
#
# * Consider how you might go about discretizing a 2D diffusion equation using finite differences.  What form would the matrix M have?
